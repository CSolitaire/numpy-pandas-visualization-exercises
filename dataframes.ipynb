# %% [markdown]
# ## Corey Solitaire
# ## 8/13
# ## Dataframes Lesson

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pydataset import data

# %% [markdown]
#    ## 1. Copy the code from the lesson to create a dataframe full of student                  grades.

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

student_grades = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(student_grades)
# Out:
# pandas.core.frame.DataFrame

# %%
# a. Create a column named passing_english that indicates whether each student has a passing grade in reading.
student_grades['passing_english'] = student_grades.english > 70
student_grades

# I crated a new column in my data frame by using the indexing operator to name my column
# I then set that name as a variable (=) to a series of boolean values using the 'english' series (.english)
# Where True represents grades greater then 70 and False represents grades less than 70
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
# b. Sort the english grades by the passing_english column. How are duplicates handled?
        
passing_english = student_grades.sort_values(by = 'passing_english')
passing_english

# The sort returns boolean values, so there are no duplicates
# To sort the grades i used the .sort_values(by) method
# This method sorts alphabetically so False values(students failing english) were displayed first
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
# c. Sort the english grades first by passing_english and then by student name. All the students that are 
#    failing english should be first, and within the students that are failing english they should be ordered 
#    alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to 
#    the .sort_values method)


sorted_grades = student_grades.sort_values(by = 'passing_english').groupby(['passing_english']).apply(lambda x: x.sort_values([
    'name'
]))
sorted_grades

# To sort the grades i used the .sort_values(by) method
# This method sorts alphabetically so False values(students failing english) were displayed first
# On top of the first .sort_values I also had too add a .groupby
# A groupby operation involves some combination of splitting the object, applying a function, and 
#  combining the results. 
# The lambda function takes the sorted and grouped data and then organizes it alphabetically by name 
# using another .sort_values
# Out:
#                        name  math  english  reading  passing_english
# passing_english
# False           11     Alan    92       62       72            False
#                 8    Albert    92       62       87            False
#                 7     Marie    93       63       90            False
#                 6    Thomas    82       64       81            False
# True            4       Ada    77       92       98             True
#                 3     Billy    98       96       88             True
#                 10    Isaac    92       99       93             True
#                 1      Jane    88       79       67             True
#                 5      John    79       76       93             True
#                 9   Richard    69       80       94             True
#                 0     Sally    62       85       80             True
#                 2     Suzie    94       74       95             True

# %%
# d. Sort the english grades first by passing_english, and then by the actual english grade, similar to 
#    how we did in the last step.
             
    
more_sorted_grades = student_grades.sort_values(by = 'passing_english').groupby(['passing_english']).apply(lambda x: x.sort_values([
    'english'
]))
more_sorted_grades

# To sort the grades i used the .sort_values(by) method
# This method sorts alphabetically so False values(students failing english) were displayed first
# On top of the first .sort_values I also had too add a .groupby
# A groupby operation involves some combination of splitting the object, applying a function, and 
#  combining the results. 
# The lambda function takes the sorted and grouped data and then organizes it by english grade ascencing
# using another .sort_values
# Out:
#                        name  math  english  reading  passing_english
# passing_english
# False           8    Albert    92       62       87            False
#                 11     Alan    92       62       72            False
#                 7     Marie    93       63       90            False
#                 6    Thomas    82       64       81            False
# True            2     Suzie    94       74       95             True
#                 5      John    79       76       93             True
#                 1      Jane    88       79       67             True
#                 9   Richard    69       80       94             True
#                 0     Sally    62       85       80             True
#                 4       Ada    77       92       98             True
#                 3     Billy    98       96       88             True
#                 10    Isaac    92       99       93             True

# %%
# e. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is 
#    the average of the math, english, and reading grades.

overall_grade = (student_grades.math + student_grades.english + student_grades.reading) / 3
#overall_grade


student_grades['overall_grade'] = overall_grade
student_grades

# To calculate the overall grade I used the vectorized operations availible in Pandas:
# 1. First I added together the students individual grades in math, english, and reading
# 2. Then I devided that total by the 3, the total number of observations to obtain the average(overall grade)
# #. Once I had a dataframe of overall_grades i added it as a colum to my student_grades data frame
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %% [markdown]
# ## 2.Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg_df = data('mpg')
mpg_df.info()

# %%
# a. How many rows and columns are there?
mpg_df.shape
# Tuple (Rows/Columns)

# %%
mpg_df.info

# %%
# b. What are the data types of each column?
mpg_df.dtypes

# %%
# c. Summarize the dataframe with .info and .describe
mpg_df.info

# %%
mpg_df.describe

# %%
# d. Rename the cty column to city.
mpg_df.rename(columns = {'cty':'city'}, inplace = True)
mpg_df

# %%
# e. Rename the hwy column to highway.
mpg_df.rename(columns = {'hwy':'highway'}, inplace = True)
mpg_df

# %%
# f. Do any cars have better city mileage than highway mileage?

#This gives the answer but I want to dig deeper
#mpg_df.sort_values(by = 'city', ascending = False)
# pd.set_option("display.max_rows", None)
# city_or_highway = mpg_df.sort_values(by = 'city').groupby(['city']).apply(lambda x: x.sort_values(['highway']))  
# city_or_highway

better_city = (mpg_df.city) >= (mpg_df.highway)
better_city.value_counts()

# %%
# g. Create a column named mileage_difference this column should contain the difference between highway 
#    and city mileage for each car.

mpg_df['mileage_difference'] = (mpg_df.highway)-(mpg_df.city)
mpg_df

# %%
# h. Which car (or cars) has the highest mileage difference?

mpg_df.sort_values(by = 'mileage_difference', ascending =False).nlargest(n=1, columns='mileage_difference',  keep='all')

# %%
# i. Which compact class car has the lowest highway mileage? The best?

compact_cars = mpg_df['class'] == 'compact'
mpg_df[compact_cars].sort_values(by = 'mileage_difference').nsmallest(n=1, columns='mileage_difference',  keep='all')



#.groupby(['passing_english'])

# %%
# Which compact class car has the best highway mileage?
mpg_df[compact_cars].sort_values(by = 'mileage_difference').nlargest(n=1, columns='mileage_difference',  keep='all')

# %%
# j. Create a column named average_mileage that is the mean of the city and highway mileage.

average_mileage = (mpg_df.city + mpg_df.highway) / 2
mpg_df['average_mileage'] = average_mileage
mpg_df

# %%
# k. Which dodge car has the best average mileage?
dodge = mpg_df['manufacturer'] == 'dodge'
mpg_df[dodge].sort_values(by = 'average_mileage').nlargest(n=1, columns='average_mileage',  keep='all')

# %%
# Which dodge car has the worst average mileage?

mpg_df[dodge].sort_values(by = 'average_mileage').nsmallest(n=1, columns='average_mileage',  keep='all')

# %% [markdown]
# ## 3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
mammals_df = data('Mammals')
mammals_df.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
# <function pydataset.data(item=None, show_doc=False)>

# %%
# a. How many rows and columns are there?

mammals_df.shape

#(62 Rows, 2 Columns)
# Out:
# (107, 4)

# %%
# b. What are the data types?

mammals_df.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
# c. Summarize the dataframe with .info and .describe

mammals_df.info
# Out:
# <bound method DataFrame.info of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
mammals_df.describe
# Out:
# <bound method NDFrame.describe of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
# d. What is the the weight of the fastest animal?
fastest = mammals_df.sort_values(by = 'speed', ascending = False)
fastest_speed = mammals_df.speed == 110.0
mammals_df.weight[fastest_speed]
# Out:
# 53    55.0
# Name: weight, dtype: float64

# %%
# e. What is the overal percentage of specials?

mammals_df.specials.value_counts() / mammals_df.specials.shape
# Out:
# False    0.906542
# True     0.093458
# Name: specials, dtype: float64

# %%
# f. How many animals are hoppers that are above the median speed?

hoppers = mammals_df.hoppers == True
hopper_df = mammals_df[hoppers]
median_hopper_speed = hopper_df.speed.median()
hoppers_above_median = hopper_df.speed > median_hopper_speed
hoppers_above_median_df = hopper_df[hoppers_above_median]
hoppers_above_median_df
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 100     2.0   64.0     True     False

# %%
# What percentage is this?

total_num_hoppers = hopper_df.shape

total_num_hoppers_above_median = hoppers_above_median_df.shape

total_percentage = total_num_hoppers_above_median[0] / total_num_hoppers[0]
total_percentage
# Out:
# 0.36363636363636365
